# %% [markdown]
# # Apparent Temperature Prediction
# In this notebook, we will build a linear regression model to predict `Apparent Temperature` using an appropriate predictor variable.
# The solution is divided into the following sections:
# - Data understanding and exploration
# - Data cleaning and preparation
# - Model building
# - Model evaluation

# %% [markdown]
# Importing required libraries

# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import axes3d

# %% [markdown]
# ### 1. Data Understanding and Exploration

# %% [markdown]
# Reading the dataset

# %%
weather_data = pd.read_csv("weather_data.csv")

# %%
weather_data.head(3)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# 1                     259          15.8263           0               1015.63
# 2                     204          14.9569           0               1015.94
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.

# %%
weather_data.shape
# Out:
# (5999, 12)

# %%
# Summary of the dataset
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 12 columns):
# Formatted Date              5999 non-null object
# Summary                     5999 non-null object
# Precip Type                 5999 non-null object
# Temperature (C)             5999 non-null float64
# Apparent Temperature (C)    5999 non-null float64
# Humidity                    5999 non-null float64
# Wind Speed (km/h)           5999 non-null float64
# Wind Bearing (degrees)      5999 non-null int64
# Visibility (km)             5999 non-null float64
# Loud Cover                  5999 non-null int64
# Pressure (millibars)        5999 non-null float64
# Daily Summary               5999 non-null object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 562.5+ KB

# %%
weather_data.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
weather_data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      5999.000000               5999.000000  5999.000000
# mean         10.217695                  8.958658     0.779488
# std          10.565425                 11.923712     0.173051
# min         -14.088889                -22.094444     0.270000
# 25%           1.094444                 -1.538889     0.680000
# 50%          10.050000                 10.050000     0.830000
# 75%          18.722222                 18.722222     0.920000
# max          34.005556                 36.400000     1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count        5999.000000             5999.000000      5999.000000      5999.0
# mean           10.007362              190.349558         9.476875         0.0
# std             6.536619              107.026792         4.038583         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             4.878300              122.000000         6.906900         0.0
# 50%             9.064300              190.000000         9.982000         0.0
# 75%            13.395200              287.000000        11.270000         0.0
# max            45.933300              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count           5999.000000
# mean             997.359828
# std              145.173638
# min                0.000000
# 25%             1012.060000
# 50%             1016.840000
# 75%             1022.490000
# max             1045.140000

# %% [markdown]
# The values in the 'Loud Cover' column have all the values as zero. This data does not explain anything. So, let us drop this column from the database. Also, the 'Daily Summary' column is not going to help us in doing any quantitative analysis. So, let's drop this table as well.

# %%
weather_data = weather_data.drop(columns=['Loud Cover'])
weather_data = weather_data.drop(columns=['Daily Summary'])
weather_data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
# 2                     204          14.9569               1015.94
# 3                     269          15.8263               1016.41
# 4                     259          15.8263               1016.51

# %% [markdown]
# #### Understanding the Data Dictionary

# %%
weather_data['Summary'].astype('category').value_counts()
# Out:
# Partly Cloudy               1791
# Mostly Cloudy               1473
# Overcast                    1230
# Clear                        853
# Foggy                        576
# Breezy and Overcast           25
# Breezy and Mostly Cloudy      20
# Breezy and Partly Cloudy       7
# Breezy and Foggy               7
# Humid and Mostly Cloudy        6
# Windy and Overcast             4
# Humid and Partly Cloudy        3
# Windy and Partly Cloudy        2
# Windy and Foggy                2
# Name: Summary, dtype: int64

# %% [markdown]
# We can notice that Most of the times weather is Cloudy (Partly or Mostly)
# <br>
# Apart from that, we can see that the data is very imbalanced. Hence, It is not adviced to use this feature for training

# %%
# Precipitation is water released from clouds in the form of rain, freezing rain, sleet, snow, or hail.
# Here we have only two types: rain and snow
weather_data['Precip Type'].astype('category').value_counts()
# Out:
# rain    4762
# snow    1237
# Name: Precip Type, dtype: int64

# %% [markdown]
# So we can notice that type of Precipitation is mostly rain.
# <br>
# Going forward, we'll convert this variables to integer so that we can use it in our model training.

# %% [markdown]
# #### Visualising the Data
# Let's now visualise our data using seaborn.

# %%
apparent_temp_df = pd.DataFrame(weather_data['Apparent Temperature (C)'])
humidity_df = pd.DataFrame(weather_data['Humidity'] * 100)
plt.scatter(humidity_df, apparent_temp_df)
plt.xlabel("Humidity")
plt.ylabel("Apparent Temperature")
plt.title("Apparent Temperature vs Humidity")
plt.show()

# %% [markdown]
# Here we can notice that for low humidity (<40), The apparent temperature is still high.
# But, As the graph is very dense, we can tell that there is no certain relationship between Humidity and Apparent Temperature that can give us any insights.
#
# So let's check the correlation for the same.

# %%
cor = weather_data.corr()
cor
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992881 -0.564260
# Apparent Temperature (C)         0.992881                  1.000000 -0.535399
# Humidity                        -0.564260                 -0.535399  1.000000
# Wind Speed (km/h)               -0.053935                 -0.126701 -0.209529
# Wind Bearing (degrees)           0.044263                  0.055151  0.041205
# Visibility (km)                  0.432098                  0.422888 -0.343168
# Pressure (millibars)            -0.080315                 -0.077491  0.061836
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                   -0.053935                0.044263
# Apparent Temperature (C)          -0.126701                0.055151
# Humidity                          -0.209529                0.041205
# Wind Speed (km/h)                  1.000000               -0.068218
# Wind Bearing (degrees)            -0.068218                1.000000
# Visibility (km)                    0.078624                0.016963
# Pressure (millibars)              -0.043172               -0.052019
#
#                           Visibility (km)  Pressure (millibars)
# Temperature (C)                  0.432098             -0.080315
# Apparent Temperature (C)         0.422888             -0.077491
# Humidity                        -0.343168              0.061836
# Wind Speed (km/h)                0.078624             -0.043172
# Wind Bearing (degrees)           0.016963             -0.052019
# Visibility (km)                  1.000000             -0.038036
# Pressure (millibars)            -0.038036              1.000000

# %%
sns.heatmap(cor, cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# - The correlation plot above suggests a negative moderate correlation between apparent temperature and humidity.
# <br>
# - However, the correlation between temperature and humidity is stronger as compared to the correlation between apparent temperature and humidity.
# <br>
# - This is because we know that humidity is directly affected by temperature value.
# <br>
# - Apart from this, we do not see any high correlation between any two independent variables which suggests that there is no multicolinearity.
# <br>
# - In case, if two independent variables are highly correlated to each other, we need to drop one of them which is least correlated with the dependent variable.

# %%
sns.distplot(apparent_temp_df )
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Here, We can notice that there are two peaks which suggests that the distribution is not normal.
# <br>
# We have two peaks for apparent temperature value ranging from (-10,0) and (10,30)

# %%
sns.boxplot(apparent_temp_df)
plt.show()

# %% [markdown]
# We can see that the distribution is not skewed and also does not have any outlier values

# %%
sns.distplot(humidity_df)
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The distribution is higly skewed towards left which can be due to presence of outliers.
# <br>
# We can confirm this by plotting a box plot.

# %%
sns.boxplot(humidity_df)
plt.show()

# %% [markdown]
# Here also, we can see that the distribution is skewed towards left and there are some outliers.

# %%
sns.jointplot(weather_data['Humidity'] * 100, weather_data['Apparent Temperature (C)'])
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The jointplot between apparent temperature and humidity suggests a moderate negative correlation between them. This correlation was also confirmed by the correlation table drafted earlier.

# %%
# Let's now make pairwise plot to see for a trend.
sns.pairplot(weather_data)
plt.show()

# %% [markdown]
# From the graphs above, you can see that in most of the cases, the data points are widely scatter all over the place. Thus, there is no clear definite trend. Also, the relationship between pressure and other parameters is somewhat uniform.
#
# Also, when there is low visibility, the humidity is high and when there is high visibility, the humidity is low.

# %%
weather_data
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 5     2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# 6     2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain
# 7     2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain
# 8     2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain
# 9     2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain
# 10    2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11    2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12    2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13    2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain
# 14    2006-04-01 14:00:00.000 +0200  Partly Cloudy        rain
# 15    2006-04-01 15:00:00.000 +0200  Partly Cloudy        rain
# 16    2006-04-01 16:00:00.000 +0200  Partly Cloudy        rain
# 17    2006-04-01 17:00:00.000 +0200  Mostly Cloudy        rain
# 18    2006-04-01 18:00:00.000 +0200  Mostly Cloudy        rain
# 19    2006-04-01 19:00:00.000 +0200  Mostly Cloudy        rain
# 20    2006-04-01 20:00:00.000 +0200  Mostly Cloudy        rain
# 21    2006-04-01 21:00:00.000 +0200  Mostly Cloudy        rain
# 22    2006-04-01 22:00:00.000 +0200  Partly Cloudy        rain
# 23    2006-04-01 23:00:00.000 +0200  Mostly Cloudy        rain
# 24    2006-04-10 00:00:00.000 +0200  Partly Cloudy        rain
# 25    2006-04-10 01:00:00.000 +0200  Partly Cloudy        rain
# 26    2006-04-10 02:00:00.000 +0200  Mostly Cloudy        rain
# 27    2006-04-10 03:00:00.000 +0200  Partly Cloudy        rain
# 28    2006-04-10 04:00:00.000 +0200  Partly Cloudy        rain
# 29    2006-04-10 05:00:00.000 +0200  Partly Cloudy        rain
# ...                             ...            ...         ...
# 5969  2006-05-14 18:00:00.000 +0200  Partly Cloudy        rain
# 5970  2006-05-14 19:00:00.000 +0200  Partly Cloudy        rain
# 5971  2006-05-14 20:00:00.000 +0200  Partly Cloudy        rain
# 5972  2006-05-14 21:00:00.000 +0200  Partly Cloudy        rain
# 5973  2006-05-14 22:00:00.000 +0200  Mostly Cloudy        rain
# 5974  2006-05-14 23:00:00.000 +0200  Mostly Cloudy        rain
# 5975  2006-05-15 00:00:00.000 +0200  Mostly Cloudy        rain
# 5976  2006-05-15 01:00:00.000 +0200  Mostly Cloudy        rain
# 5977  2006-05-15 02:00:00.000 +0200  Partly Cloudy        rain
# 5978  2006-05-15 03:00:00.000 +0200  Mostly Cloudy        rain
# 5979  2006-05-15 04:00:00.000 +0200       Overcast        rain
# 5980  2006-05-15 05:00:00.000 +0200  Mostly Cloudy        rain
# 5981  2006-05-15 06:00:00.000 +0200  Mostly Cloudy        rain
# 5982  2006-05-15 07:00:00.000 +0200       Overcast        rain
# 5983  2006-05-15 08:00:00.000 +0200       Overcast        rain
# 5984  2006-05-15 09:00:00.000 +0200       Overcast        rain
# 5996                     170           9.9820               1020.99
# 5997                     201          15.8263               1021.50
# 5998                     191          14.9569               1021.64
#
# [5999 rows x 10 columns]

# %% [markdown]
# ## Data cleaning and preparation
#
# Let's now conduct some data cleaning steps.
#
# We've seen that there are no missing values in the dataset.
#
# We saw some outliers in Humidity. Lets check the percentage of outlier values and handle accordingly

# %% [markdown]
# From the boxplot, we have noticed that the outliers are on the right side i.e. values lesser than Q1-1.5*IQR.
# <br>
# We'll use the Inter Quantile Range to find out the outliers.

# %%
Q1 = weather_data.Humidity.quantile(0.25)
Q3 = weather_data.Humidity.quantile(0.75)
## Finding IQR
IQR = Q3 - Q1
## Finding lower boundary for thresholding outlier values
lower_boundary = Q1 - 1.5 * IQR
## Printing some outlier values
humidity_outliers = weather_data.Humidity[weather_data.Humidity < lower_boundary]

# %%
## Checking the percentage of outlier values
(len(humidity_outliers)/len(weather_data)) * 100
# Out:
# 0.9334889148191364

# %% [markdown]
# As the % of outlier values is less than 1%, we can easily drop them

# %%
weather_data = weather_data[weather_data.Humidity > lower_boundary]

# %% [markdown]
# Now we'll check the distribution and also draw a boxplot to verify the same.

# %%
sns.distplot(weather_data.Humidity)
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.boxplot(weather_data.Humidity)
plt.show()

# %% [markdown]
# Though the distribution is still skewed, We can see that all the outlier values have been removed.

# %% [markdown]
# Now, we'll create dummy variables for `precip type` to convert it to integer

# %%
weather_data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)'],
#       dtype='object')

# %%
# Convert into dummies
weather_data['Precip Type'] = pd.get_dummies(weather_data['Precip Type'], drop_first=True)
weather_data.head()
# Out:
#                   Formatted Date        Summary  Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy            0         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy            0         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy            0         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy            0         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy            0         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
# 2                     204          14.9569               1015.94
# 3                     269          15.8263               1016.41
# 4                     259          15.8263               1016.51

# %% [markdown]
# ### Feature Engineering
# - Creating new column from existing one's which can be useful for model training

# %% [markdown]
# Let's check the `temperature` values.

# %%
weather_data.describe()["Temperature (C)"]
# Out:
# count    5943.000000
# mean       10.051498
# std        10.467074
# min       -14.088889
# 25%         1.083333
# 50%         9.977778
# 75%        18.183333
# max        34.005556
# Name: Temperature (C), dtype: float64

# %% [markdown]
# We can divide the Temperature values into 3 different bins, namely: `low`, `medium`, `high`
# <br>
# We'll use the quantile values to create this bins

# %%
# Fetching the 3 quantiles
Q1 = weather_data["Temperature (C)"].quantile(0.25)
Q2 = weather_data["Temperature (C)"].quantile(0.5)
Q3 = weather_data["Temperature (C)"].quantile(0.75)

# Creating a function to convert continous temperature values into 3 bins

def convert_temp(x):
    if x <= Q1:
        return 'low'
    elif (x > Q1) and (x < Q3):
        return 'medium'
    else:
        return 'high'

# %%
# Applying the function
weather_data['Temperature_Bins'] = weather_data["Temperature (C)"].apply(convert_temp)

# %%
# Convert into dummies
dummies = pd.get_dummies(weather_data['Temperature_Bins'], drop_first=True)
dummies.head()
# Out:
#    low  medium
# 0    0       1
# 1    0       1
# 2    0       1
# 3    0       1
# 4    0       1

# %%
# Merging dummy variables in dataset
weather_data = pd.concat([weather_data,dummies], axis=1)

# %%
# Dropping all unnecesarry columns from our Analysis

weather_data.drop(['Formatted Date','Summary','Temperature_Bins'],axis=1, inplace=True)

# %% [markdown]
# As we have created a derived feature here, i.e. created new features from existing column, It is necessary to check the correlation between those features as there will be higher chances that both old features and new derived features can be highly correlated with each other.
# <br>
# If they are highly correlated, then we need to drop the old feature and only keep the new one.

# %%
weather_data[['Temperature (C)', 'low', 'medium', 'Apparent Temperature (C)']].corr()
# Out:
#                           Temperature (C)       low    medium  \
# Temperature (C)                  1.000000 -0.700055 -0.054033
# low                             -0.700055  1.000000 -0.577576
# medium                          -0.054033 -0.577576  1.000000
# Apparent Temperature (C)         0.992809 -0.696956 -0.040222
#
#                           Apparent Temperature (C)
# Temperature (C)                           0.992809
# low                                      -0.696956
# medium                                   -0.040222
# Apparent Temperature (C)                  1.000000

# %% [markdown]
# Here, we can notice that the correlation between `low` (derived feature) & `Temperature (C)` is higher.
# <br>
# In general scenario we would remove the `Temperature (C)` variable but here you can see that this column is very highly correlated with our dependent variable hence by removing it we may loose an important feature from our model. So, we'll keep this variable (for this particular case).

# %% [markdown]
# ### Scaling
#
# Now we need to scale the variables for better interpretability.
# <br>
# As all the final independent variables in our dataset are numeric, we'll scale all the variables
# <br>
# Let's scale all these columns using StandardScaler.
# You can use any other scaling method as well; it is totally up to you.

# %%
# Import the StandardScaler()
from sklearn.preprocessing import StandardScaler

# Create a scaling object
scaler = StandardScaler()

X = weather_data.drop('Apparent Temperature (C)',1)
X[X.columns] = scaler.fit_transform(X)

# %%
y = weather_data['Apparent Temperature (C)']

# %% [markdown]
# #### Train-Test Split
#
# You now need to split our variable into training and testing sets. You'll perform this by importing `train_test_split` from the `sklearn.model_selection` library. It is usually a good practice to keep 70% of the data in your train dataset and the rest 30% in your test dataset

# %%
# Split the datafram into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ---
# ### Building the first Linear Regression model with all the features
#
# Equation of linear regression<br>
# $y = c + m_1x_1 + m_2x_2 + ... + m_nx_n$
#
# -  $y$ is the response
# -  $c$ is the intercept
# -  $m_1$ is the coefficient for the first feature
# -  $m_n$ is the coefficient for the nth feature<br>
#
# In our case:
#
# $y = c + m_1 \times Humidity$
#
# The $m$ values are called the model **coefficients** or **model parameters**.
#
# ---

# %%
# Instantiate
lm = LinearRegression()

# Fit a line
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.score(X_train, y_train)
# Out:
# 0.9919920926211807

# %% [markdown]
# So we can notice that our model is currently 99.1% accurate. Now, let's remove the `Temperature (C)` column which is most correlated with y and check whether it affects the model's performance or not.

# %%
# Instantiate
lm = LinearRegression()

# Fit a line
lm.fit(X_train.drop('Temperature (C)', 1), y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.score(X_train.drop('Temperature (C)', 1) ,y_train)
# Out:
# 0.8246675089864143

# %% [markdown]
# So here it is. As soon as we remove the most correlated feature, our accuracy goes down in a giffy from 99.2% to 82.4%.
# <br>
# Hence it is neccesarry to keep all independent columns which are highly correlated with the dependent column.

# %% [markdown]
# #### Model Building Using RFE
#
# Now, you have close to 9 features. It is not adviced to manually eliminate these features. So let's now build a model using recursive feature elimination to select features.
#
# We'll first start off by finding out the optimal number of features using RFECV, and then use the `statsmodels` library to build models using the shortlisted features (this is also because `SKLearn` doesn't have `Adjusted R-squared` that `statsmodels` has).

# %%
from sklearn.feature_selection import RFECV
rfecv = RFECV(estimator=lm, step=1, cv=3)
rfecv.fit(X_train, y_train)
print("Optimal number of features : %d" % rfecv.n_features_)
# Out:
# Optimal number of features :
# 2963               -0.030023        -0.881951              0.258152  1.728754
# 1343                0.728369        -0.365889              0.073668 -0.578451
# 1902               -1.219108        -1.580620              0.264475  1.728754
# 3303               -0.357724         0.428052              0.234056  1.728754
# 1682               -1.331462        -1.902166              0.192536 -0.578451
# 4423               -1.565534        -1.695741              0.190007 -0.578451
# 2803                1.524213         0.126355              0.205111  1.728754
# 5153               -1.509357         0.443931              0.041702 -0.578451
# 805                -1.134842         0.443931              0.065589 -0.578451
# 5696               -0.076838         0.428052              0.010440 -0.578451
# 5748                1.252690        -0.473071              0.085751  1.728754
# 4190                1.009255         0.487598              0.091793 -0.578451
# 1893                0.719006        -0.826375              0.248036 -0.578451
# 350                -1.106754         0.412174              0.127973 -0.578451
# 79                  1.477399        -0.770799              0.040578 -0.578451
# 3965               -0.282821         1.424449              0.141321 -0.578451
# 5690               -0.170466         1.567359              0.032851 -0.578451
#
#         medium
# 2895  1.001516
# 2892  1.001516
# 919   1.001516
# 883  -0.998487
# 5193 -0.998487
# 5962 -0.998487
# 4891 -0.998487
# 5346  1.001516
# 1250 -0.998487
# 1315  1.001516
# 3714 -0.998487
# 2747 -0.998487
# 3264 -0.998487
# 1860  1.001516
# 1719  1.001516
# 3121 -0.998487
# 1172 -0.998487
# 1090 -0.998487
# 949  -0.998487
# 777  -0.998487
# 4588  1.001516
# 1316  1.001516
# 2361 -0.998487
# 4350  1.001516
# 957  -0.998487
# 848   1.001516
# 414   1.001516
# 362   1.001516
# 4916  1.001516
# 2990 -0.998487
# ...        ...
# 4066 -0.998487
# 2654  1.001516
# 1031 -0.998487
# 4756  1.001516
# 5895  1.001516
# 3216 -0.998487
# 5041  1.001516
# 2466  1.001516
# 1903 -0.998487
# 5837  1.001516
# 2437  1.001516
# 5819  1.001516
# 1534  1.001516
# 2963 -0.998487
# 1343  1.001516
# 1902 -0.998487
# 3303 -0.998487
# 1682  1.001516
# 4423  1.001516
# 2803 -0.998487
# 5153  1.001516
# 805  -0.998487
# 5696  1.001516
# 5748 -0.998487
# 4190 -0.998487
# 1893  1.001516
# 350  -0.998487
# 79    1.001516
# 3965 -0.998487
# 5690  1.001516
#
# [4160 rows x 9 columns]

# %% [markdown]
# ### Building a Linear Model using statsmodels
#
# By default, the `statsmodels` library fits a line on the dataset which passes through the origin. But in order to have an intercept, you need to manually use the `add_constant` attribute of `statsmodels`. And once you've added the constant to your `X_train` dataset, you can go ahead and fit a regression line using the `OLS` (Ordinary Least Squares) attribute of `statsmodels` as shown below

# %%
# Import statsmodels
import statsmodels.api as sm  

# Subset the features selected by rfe1
col1 = X_train.columns[rfe1.support_]

# Subsetting training data for 18 selected columns
X_train_rfe1 = X_train[col1]

# Add a constant to the model
X_train_rfe1 = sm.add_constant(X_train_rfe1)
X_train_rfe1.head()
# Out:
#       const  Precip Type  Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2895    1.0    -0.512695        -0.296335 -0.262349           2.683983
# 2892    1.0    -0.512695        -0.491142 -0.083316           1.745448
# 919     1.0    -0.512695         0.727597  0.334428           0.150923
# 883     1.0    -0.512695         1.319449 -1.455903          -1.055413
# 5193    1.0     1.950478        -1.168455  1.050560           4.062301
#
#       Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)       low  \
# 2895               -0.479441         0.428052              0.085049 -0.578451
# 2892               -0.385812         0.428052              0.097062 -0.578451
# 919                -0.554344         0.126355              0.101699 -0.578451
# 883                 0.522386         0.428052              0.115890 -0.578451
# 5193               -1.593623        -2.247531              0.118138  1.728754
#
#         medium
# 2895  1.001516
# 2892  1.001516
# 919   1.001516
# 883  -0.998487
# 5193 -0.998487

# %%
X_train_rfe1.shape
# Out:
# (4160, 10)

# %%
# Fitting the model with 18 variables

lm1 = sm.OLS(y_train, X_train_rfe1).fit()   

# Performing a summary operation lists out all the different parameters of the regression line fitted

print(lm1.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.992
# Model:                                  OLS   Adj. R-squared:                  0.992
# Method:                       Least Squares   F-statistic:                 5.712e+04
# Date:                      Fri, 04 Dec 2020   Prob (F-statistic):               0.00
# Time:                              20:20:44   Log-Likelihood:                -6168.2
# No. Observations:                      4160   AIC:                         1.236e+04
# Df Residuals:                          4150   BIC:                         1.242e+04
# Df Model:                                 9
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      8.7831      0.017    530.716      0.000       8.751       8.816
# Precip Type                0.0988      0.036      2.737      0.006       0.028       0.170
# Temperature (C)           12.0612      0.041    294.472      0.000      11.981      12.141
# Humidity                   0.0239      0.022      1.077      0.281      -0.020       0.067
# Wind Speed (km/h)         -0.8959      0.018    -50.661      0.000      -0.931      -0.861
# Wind Bearing (degrees)     0.0584      0.017      3.479      0.001       0.026       0.091
# Visibility (km)           -0.0194      0.019     -1.006      0.315      -0.057       0.018
# Pressure (millibars)      -0.0265      0.017     -1.516      0.130      -0.061       0.008
# low                        0.3840      0.053      7.292      0.000       0.281       0.487
# medium                     0.5423      0.034     16.149      0.000       0.476       0.608
# ==============================================================================
# Omnibus:                      440.113   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              614.726
# Skew:                           0.831   Prob(JB):                    3.27e-134
# Kurtosis:                       3.886   Cond. No.                         7.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ####  Looking at some key statistics from the summary

# %% [markdown]
# The values we are concerned with are -
#
# 1. The coefficients and significance (p-values)
# 2. R-squared
# 3. F statistic and its significance

# %% [markdown]
# ##### 1. The coefficients should have very low p value (<0.05)
# The coefficient is statistically significant. So the association is not purely by chance.

# %% [markdown]
# ##### 2. R - squared is 0.992
# Meaning that 99.2% of the variance in `Apparent Temperature` is explained by these variables
#
# This is a very good R-squared value.

# %% [markdown]
# ##### 3. F statistic should have a very low p value (practically low)
# Meaning that the model fit is statistically significant, and the explained variance isn't purely by chance.## New markdown cell

# %% [markdown]
# Hence, The model seems to be doing a good job.
# <br>
# Let's also quickly take a look at the VIF values.

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_rfe1.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe1.values, i) for i in range(X_train_rfe1.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features    VIF
# 8                     low  10.19
# 2         Temperature (C)   6.23
# 1             Precip Type   4.79
# 9                  medium   4.12
# 3                Humidity   1.82
# 6         Visibility (km)   1.33
# 4       Wind Speed (km/h)   1.16
# 5  Wind Bearing (degrees)   1.02
# 7    Pressure (millibars)   1.02
# 0                   const   1.00

# %% [markdown]
# Notice that the highest value VIF is 10.19 which is greater than the optimal cut-off of 5. These variables isn't of use. Hence we'll drop this column and rebuild our model.

# %%
# Dropping "low"
X_train_rfe1.drop("low",1,inplace=True)

# %%
# Fitting the model with 18 variables

lm1 = sm.OLS(y_train, X_train_rfe1).fit()   

# Performing a summary operation lists out all the different parameters of the regression line fitted

print(lm1.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.992
# Model:                                  OLS   Adj. R-squared:                  0.992
# Method:                       Least Squares   F-statistic:                 6.346e+04
# Date:                      Fri, 04 Dec 2020   Prob (F-statistic):               0.00
# Time:                              20:21:30   Log-Likelihood:                -6194.7
# No. Observations:                      4160   AIC:                         1.241e+04
# Df Residuals:                          4151   BIC:                         1.246e+04
# Df Model:                                 8
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      8.7832      0.017    527.421      0.000       8.751       8.816
# Precip Type                0.2249      0.032      7.053      0.000       0.162       0.287
# Temperature (C)           11.8685      0.031    376.820      0.000      11.807      11.930
# Humidity                   0.0229      0.022      1.024      0.306      -0.021       0.067
# Wind Speed (km/h)         -0.8987      0.018    -50.515      0.000      -0.934      -0.864
# Wind Bearing (degrees)     0.0646      0.017      3.829      0.000       0.032       0.098
# Visibility (km)           -0.0269      0.019     -1.387      0.166      -0.065       0.011
# Pressure (millibars)      -0.0294      0.018     -1.671      0.095      -0.064       0.005
# medium                     0.3754      0.025     15.181      0.000       0.327       0.424
# ==============================================================================
# Omnibus:                      417.782   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              566.213
# Skew:                           0.817   Prob(JB):                    1.12e-123
# Kurtosis:                       3.772   Cond. No.                         4.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_rfe1.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe1.values, i) for i in range(X_train_rfe1.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features   VIF
# 1             Precip Type  3.69
# 2         Temperature (C)  3.64
# 8                  medium  2.21
# 3                Humidity  1.82
# 6         Visibility (km)  1.33
# 4       Wind Speed (km/h)  1.16
# 5  Wind Bearing (degrees)  1.02
# 7    Pressure (millibars)  1.02
# 0                   const  1.00

# %% [markdown]
# The large VIFs have now dropped to a workable value. But from the p-value perspective, `Humidity` has become insignificant. So let's drop that.

# %%
X_train_rfe1.drop('Humidity', axis = 1, inplace = True)

# %%
# Fitting the model with 18 variables

lm1 = sm.OLS(y_train, X_train_rfe1).fit()   

# Performing a summary operation lists out all the different parameters of the regression line fitted

print(lm1.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.992
# Model:                                  OLS   Adj. R-squared:                  0.992
# Method:                       Least Squares   F-statistic:                 7.252e+04
# Date:                      Fri, 04 Dec 2020   Prob (F-statistic):               0.00
# Time:                              20:21:33   Log-Likelihood:                -6195.2
# No. Observations:                      4160   AIC:                         1.241e+04
# Df Residuals:                          4152   BIC:                         1.246e+04
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      8.7830      0.017    527.449      0.000       8.750       8.816
# Precip Type                0.2214      0.032      6.984      0.000       0.159       0.284
# Temperature (C)           11.8549      0.029    415.376      0.000      11.799      11.911
# Wind Speed (km/h)         -0.9045      0.017    -53.708      0.000      -0.938      -0.872
# Wind Bearing (degrees)     0.0657      0.017      3.899      0.000       0.033       0.099
# Visibility (km)           -0.0304      0.019     -1.592      0.111      -0.068       0.007
# Pressure (millibars)      -0.0291      0.018     -1.653      0.098      -0.064       0.005
# medium                     0.3796      0.024     15.565      0.000       0.332       0.427
# ==============================================================================
# Omnibus:                      411.233   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              556.215
# Skew:                           0.807   Prob(JB):                    1.66e-121
# Kurtosis:                       3.776   Cond. No.                         3.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# We can still see that the `Visibility (km)` column has a higher p-values. Let's drop that variable and retrain our model

# %%
X_train_rfe1.drop('Visibility (km)', axis = 1, inplace = True)

# %%
# Fitting the model with 18 variables

lm1 = sm.OLS(y_train, X_train_rfe1).fit()   

# Performing a summary operation lists out all the different parameters of the regression line fitted

print(lm1.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.992
# Model:                                  OLS   Adj. R-squared:                  0.992
# Method:                       Least Squares   F-statistic:                 8.458e+04
# Date:                      Fri, 04 Dec 2020   Prob (F-statistic):               0.00
# Time:                              20:21:35   Log-Likelihood:                -6196.5
# No. Observations:                      4160   AIC:                         1.241e+04
# Df Residuals:                          4153   BIC:                         1.245e+04
# Df Model:                                 6
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      8.7828      0.017    527.353      0.000       8.750       8.815
# Precip Type                0.2208      0.032      6.965      0.000       0.159       0.283
# Temperature (C)           11.8411      0.027    435.201      0.000      11.788      11.894
# Wind Speed (km/h)         -0.9064      0.017    -53.937      0.000      -0.939      -0.873
# Wind Bearing (degrees)     0.0657      0.017      3.900      0.000       0.033       0.099
# Pressure (millibars)      -0.0290      0.018     -1.649      0.099      -0.064       0.005
# medium                     0.3744      0.024     15.488      0.000       0.327       0.422
# ==============================================================================
# Omnibus:                      410.844   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              555.921
# Skew:                           0.806   Prob(JB):                    1.92e-121
# Kurtosis:                       3.780   Cond. No.                         3.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Again we can notice that the `Pressure (millibars)` column has a higher p-value. We need to drop that too## New markdown cell

# %%
X_train_rfe1.drop('Pressure (millibars)', axis = 1, inplace = True)

# %%
# Fitting the model with 18 variables

lm1 = sm.OLS(y_train, X_train_rfe1).fit()   

# Performing a summary operation lists out all the different parameters of the regression line fitted

print(lm1.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.992
# Model:                                  OLS   Adj. R-squared:                  0.992
# Method:                       Least Squares   F-statistic:                 1.014e+05
# Date:                      Fri, 04 Dec 2020   Prob (F-statistic):               0.00
# Time:                              20:21:44   Log-Likelihood:                -6197.8
# No. Observations:                      4160   AIC:                         1.241e+04
# Df Residuals:                          4154   BIC:                         1.245e+04
# Df Model:                                 5
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      8.7824      0.017    527.271      0.000       8.750       8.815
# Precip Type                0.2217      0.032      6.993      0.000       0.160       0.284
# Temperature (C)           11.8440      0.027    436.071      0.000      11.791      11.897
# Wind Speed (km/h)         -0.9047      0.017    -53.927      0.000      -0.938      -0.872
# Wind Bearing (degrees)     0.0676      0.017      4.019      0.000       0.035       0.101
# medium                     0.3756      0.024     15.545      0.000       0.328       0.423
# ==============================================================================
# Omnibus:                      409.206   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              552.421
# Skew:                           0.805   Prob(JB):                    1.10e-120
# Kurtosis:                       3.770   Cond. No.                         3.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# All the VIF values and p-values seem to be in a good range. Also the `Adjusted R-squared` value has not dropped from `0.992` with **9 variables** to **5 variables**. This model is explaining most of the variance without being too complex. So let's proceed with this model.

# %% [markdown]
# ## Residual analysis
# To validate assumptions of the model, and hence the reliability for inference

# %% [markdown]
# #### Distribution of the error terms
# We need to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
y_train_pred = lm1.predict(X_train_rfe1)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
fig.suptitle('Error Terms', fontsize = 15)                  # Plot heading 
plt.xlabel('Errors', fontsize = 15)         # X-label
plt.show()
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The residuals are following a somewhat normally distributed pattern with a mean negative mean. This seems okay.
